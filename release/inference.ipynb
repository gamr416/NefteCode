# %% [markdown]
# # Inference - K-Fold (5 runs averaged)

# %%
import subprocess
import sys
from pathlib import Path

release_dir = Path(".").resolve()
result = subprocess.run(
    [sys.executable, "solution.py"],
    cwd=str(release_dir),
    capture_output=True,
    text=True,
)
print(result.stdout)
if result.returncode != 0:
    print(result.stderr)
    raise RuntimeError(f"solution.py exited with {result.returncode}")

# %%
import pandas as pd
df = pd.read_csv("predictions.csv")
print(df.head(10))
